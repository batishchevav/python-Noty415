# %%
a=0
for x in range (5):
    a +=3*x
print(a)
# Out:
# 30

# %%
a=1
for x in range (1,5):
    a *=2*x
print(a)
# Out:
# 384

# %%
def equalition(x):
    return x+2

# %%
# !pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\Игорь\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib

# %%
array=[equalition(x) for x in range(0,1000)]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(array)

# %%
def aboba (x):
    return (x**2+2)
S = aboba (x)
arra=[aboba(x) for x in range (-1000,1000)]
import matplotlib.pyplot as plt
plt.plot(arra)

# %%
def aboba (x):
    return (x**3)
S = aboba (x)
arr=[aboba(x) for x in range (-1000,1000)]
import matplotlib.pyplot as plt
plt.plot(arr)

# %%
import math
import numpy as np

# %%
np.arange(0, math.pi, 0.0001)
# Out:
# array([0.0000e+00, 1.0000e-04, 2.0000e-04, ..., 3.1413e+00, 3.1414e+00,
#        3.1415e+00])

# %%
def er (x):
    return (math.sin(x)*(((math.cos(x)^(1/4))/(math.sin(x)+7/5))-2*math.sin(x)+2))
S = er (x)
ar=[er(x) for x in range (-1000,1000)]
import matplotlib.pyplot as plt
plt.plot(er)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\D395~1\AppData\Local\Temp/ipykernel_5380/130080617.py in <module>
#       1 def er (x):
#       2     return (math.sin(x)*(((math.cos(x)^(1/4))/(math.sin(x)+7/5))-2*math.sin(x)+2))
# ----> 3 S = er (x)
#       4 ar=[er(x) for x in range (-1000,1000)]
#       5 import matplotlib.pyplot as plt
#
# C:\Users\D395~1\AppData\Local\Temp/ipykernel_5380/130080617.py in er(x)
#       1 def er (x):
# ----> 2     return (math.sin(x)*(((math.cos(x)^(1/4))/(math.sin(x)+7/5))-2*math.sin(x)+2))
#       3 S = er (x)
#       4 ar=[er(x) for x in range (-1000,1000)]
#       5 import matplotlib.pyplot as plt
#
# TypeError: unsupported operand type(s) for ^: 'float' and 'float'
